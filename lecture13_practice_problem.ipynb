# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## 문제 1. drug 데이터셋을 활용한 데이터 분석 및 시각화

# %% [markdown]
# #### < Data description >
#   - 각 행은 사건이 발생한 지역, 연도, 월, 복용 약물, 복용량의 정보가 포함되어있음
#   - A data frame with 23659 rows × 6 columns
#   - Columns
#     - State : 지역 약어
#     - Year : 연도
#     - Month : 월
#     - Indicator : 약물 이름
#     - Data Value : 복용량
#     - State Name : 지역 full name

# %% [markdown]
# ### Q1.1) drug 데이터셋을 활용하여 연도별 지역별 약물 복용 사망자 수를 bar plot으로 시각화하시오

# %% [markdown]
# ### Q1.2) drug 데이터셋을 활용하여 가장 사망자를 많이 발생시킨 약물을 찾고 연도별 사망자 추이를 bar plot과 line plot으로 시각화하여 살펴보시오
# - fig, ax = plt.subplots(nrows=1,ncols=2,figsize=(12,6))

# %%
# Out:
# Text(0.5, 1.0, 'Opioids (T40.0-T40.4,T40.6)')

# %% [markdown]
# ### Q1.3) drug 데이터셋을 활용하여 약물별 복용량의 분포를 boxplot과 violin plot으로 시각화하여 결과를 살펴보시오

# %%
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3025: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try boxplot
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3025: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try violinplot
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ### Q1.4) drug 데이터셋을 활용하여 사망자기록이 500건 이상인 도시의 약물별 사망자 수의 추이를 시각화하시오
# - horizental bar plot을 사용하시오

# %%
# Out:
# <Axes: xlabel='count', ylabel='Indicator'>

# %% [markdown]
# ## 문제 2. diamonds 데이터셋을 활용한 데이터 분석 및 시각화

# %% [markdown]
# #### < Data description >
#   - A data frame with 53,940 rows and 10 variables:
#   - Columns
#     - Price : price in US dollars ($326--$18,823)
#     - Carat : weight of the diamond (0.2--5.01)
#     - Cut	: quality of the cut (Fair, Good, Very Good, Premium, Ideal)
#     - Color : diamond colour, from J (worst) to D (best)
#     - Clarity : a measurement of how clear the diamond is (I1 (worst), SI2, SI1, VS2, VS1, VVS2, VVS1, IF (best))
#     - X	: length in mm (0--10.74)
#     - Y : width in mm (0--58.9)
#     - Z	: depth in mm (0--31.8)
#     - Depth : total depth percentage = z / mean(x, y) = 2 * z / (x + y) (43--79)
#     - Table : width of top of diamond relative to widest point (43--95)

# %% [markdown]
# ### Q2.1) diamonds데이터셋을 활용하여 여러 변수들과 가격의 관계를 살펴보기위한 기본 그래프를 작성하고 이 그래프를 해석해보시오
# - continuous column과 price column은 scatterplot으로 표현하시오
# - categorical column과 price column은 boxplot으로 그래프를 나타내시오
# - 그래프를 Grid로 표현하기위해서는 ax설정을 고려해야합니다(아래의 코드를 참고하세요)
#   - fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(18,10))

# %% [markdown]
# - Answer :

# %% [markdown]
# ### Q2.2) diamonds 데이터셋을 활용하여 x,y,z가 모두 1Q ~ 3Q 사이에 있는 데이터만 선별하여 cut, color 두 컬럼과 가격의 관계를 시각화하고, 가장 비싼 다이아몬드에대하여 설명하시오.
# - x = 1Q ~ 3Q, y = 1Q ~ 3Q, z = 1Q ~ 3Q 모두 동시에 만족하는 다이아몬드만 추출하셔야합니다.(1Q : 25%, 3Q: 75%값)
#
# - 시각화는 boxenplot을 사용하시기 바랍니다.
#
# - 또한, color 그룹은 D->E->F->G->H->I->J와 같이 사전적으로 정렬하여 시각화해주시기바랍니다.
# - fig 사이즈는 아래의 코드를 활용하세요
#   - fig, ax = plt.subplots( figsize=(18,10) )

# %% [markdown]
# - Answer :

# %% [markdown]
# # 문제 3. diamond & drug over dose 데이터셋을 활용하여 각 데이터셋마다 하나의 질문을 셍성하여 시각화하시오
# - 문제 정의시 왜 이러한 시각화가 필요한지 이유를 설명하시오(의미 있는 시각화/insight가 있어야 함)
#
# ### Q3.1 diamond dataset Qeustion
# ### Q3.2 drug overdose dataset Qeustion
